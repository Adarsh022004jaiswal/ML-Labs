# %%
import pandas as pd
data = pd.read_excel(r"D:\ML_dataset3.xlsx", nrows=100)
print(data)
# Out:
#       Country  Year         Disease Name Disease Category  \
# 0       Italy  2013              Malaria      Respiratory
# 1      France  2002                Ebola        Parasitic
# 2      Turkey  2015             COVID-19          Genetic
# 3   Indonesia  2011  Parkinson's Disease       Autoimmune
# 4       Italy  2013         Tuberculosis          Genetic
# ..        ...   ...                  ...              ...
# 95  Argentina  2012              Malaria          Genetic
# 96     Brazil  2021              Malaria        Parasitic
# 97      China  2013               Cancer            Viral
# 98     Brazil  2009               Rabies       Autoimmune
# 99     Russia  2012               Asthma          Chronic
#
#     Prevalence Rate (%)  Incidence Rate (%)  Mortality Rate (%) Age Group  \
# 0                  0.95                1.55                8.42      0-18
# 1                 12.46                8.63                8.75       61+
# ...

# %%
# Function to detect and handle outliers using IQR
def handle_outliers(df, column):
    Q1 = df[column].quantile(0.25)  # First quartile
    Q3 = df[column].quantile(0.75)  # Third quartile
    IQR = Q3 - Q1  # Interquartile Range
    
    # Define bounds for detecting outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Replace outliers with upper or lower bound
    df[column] = df[column].clip(lower=lower_bound, upper=upper_bound)

# Detect and handle outliers for numerical columns
numeric_columns = data.select_dtypes(include=["number"]).columns
for column in numeric_columns:
    handle_outliers(data, column)

print("\nOutliers handled for numeric columns.")
# Out:
# Outliers handled for numeric columns.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Correct file path and use read_excel
data = pd.read_excel(r"D:\ML_dataset3.xlsx")

# Example visualization: Disease Category distribution
sns.countplot(data=data, x="Disease Category", palette="Set2")
plt.title("Distribution of Disease Categories")
plt.xlabel("Disease Category")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

import seaborn as sns
data=pd.read_excel()
sns.countplot(data=data, x="Dieases Category", palette="Set2")
plt.title("Distribution of disease categories")
import seaborn as sns
sns.countplot(data=data, x="Disease Category", palatte="Set2")
plt.title("
# Out:
#   Cell In[11], line 22
#     plt.title("
#               ^
# SyntaxError: unterminated string literal (detected at line 22)

# %%
sns.countplot(data=data, x="Country", palette="Set3")
plt.title("Diseases by Country")
plt.xlabel("Country")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\adars\AppData\Local\Temp\ipykernel_5864\3303611064.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x="Country", palette="Set3")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 sns.countplot(data=data, x="Country", palette="Set3")
# ----> 2 plt.title("Diseases by Country")
#       3 plt.xlabel("Country")
#       4 plt.ylabel("Count")
#
# NameError: name 'plt' is not defined

# %%
sns.countplot(data=data, x="Gender", hue="Disease Category", palette="coolwarm")
plt.title("Gender Distribution by Disease Category")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 sns.countplot(data=data, x="Gender", hue="Disease Category", palette="coolwarm")
# ----> 2 plt.title("Gender Distribution by Disease Category")
#       3 plt.xlabel("Gender")
#       4 plt.ylabel("Count")
#
# NameError: name 'plt' is not defined

# %%
import seaborn as sns
sns.countplot(data=data, x="Availability of Vaccines/Treatment", palette="viridis")
plt.title("Availability of Vaccines/Treatment")
plt.xlabel("Availability")
plt.ylabel("Count")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 import seaborn as sns
# ----> 2 sns.countplot(data=data, x="Availability of Vaccines/Treatment", palette="viridis")
#       3 plt.title("Availability of Vaccines/Treatment")
#       4 plt.xlabel("Availability")
#
# NameError: name 'data' is not defined

# %%
sns.countplot(data=data, x="Treatment Type", hue="Disease Name", palette="Set1")
plt.title("Treatment Types by Disease")
plt.xlabel("Treatment Type")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
